# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

tokenizer = RegexpTokenizer(r'\w+')

# create English stop words list
en_stop = get_stop_words('en')
#en_stop=[]
# Create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()
    
# create sample documents
doc_a = "Brocolli is good to eat. My brother likes to eat good brocolli, but not my mother."
doc_b = "My mother spends a lot of time driving my brother around to baseball practice."
doc_c = "Some health experts suggest that driving may cause increased tension and blood pressure."
doc_d = "I often feel pressure to perform well at school, but my mother never seems to drive my brother to do better."
doc_e = "Health professionals say that brocolli is good for your health." 
dataset = fetch_20newsgroups(shuffle=True, random_state=1,
                             remove=('headers', 'footers', 'quotes'))
n_samples=1000
#:n_samples
data_samples = dataset.data[:]
# compile sample documents into a list
#doc_set = [doc_a, doc_b, doc_c, doc_d, doc_e]
doc_set=data_samples
# list for tokenized documents in loop
texts = []

# loop through document list
for i in doc_set:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    #stopped_tokens = [i for i in tokens if not i in en_stop]
    
    # stem tokens
    #stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    stemmed_tokens = stopped_tokens
    # add tokens to list
    texts.append(stemmed_tokens)

# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)
    
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

print(len(data_samples))
print(len(texts))

dic = set()

for word in open("20news.dict", "r"):
    dic.update(set(word))
    newText= []
for line in texts: 
    lineWordSet = set(line)
    for w in lineWordSet:
        if w in dic:
            newText.append(line)
            break
texts=newText
print(len(texts))
import random
f=open("20news.txt", "w")
for  i in [0]:
    for line in texts:
    #index = random.randint(0,len(texts)-1)
        #print(line)
        f.write(" ".join(line)+"\n" )
f.close()
print("done")
# generate LDA model
#ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=2, id2word = dictionary, passes=20)
# Out:
# 11314
# 11314
# 8329
# done

# %%
en_stop
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  "can't",
#  'cannot',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  "let's",
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
# ...

# %%
def is_number(s):
    try:
        float(s)
        int(s)
        return True
    except ValueError:
        pass
 
    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
 
    return False

dic = set()
for line in texts:
    for d in line:
        #print(d)
        if( (not is_number(d) )and len(d)>2):
            dic.update(d)
dic
# Out:
# well
# m
# sure
# story
# nad
# seem
# biased
# disagree
# statement
# u
# s
# media
# ruin
# israels
# reputation
# rediculous
# u
# s
# media
# pro
# israeli
# media
# world
# lived
# europe
# realize
# incidences
# one
# described
# letter
# occured
# u
# s
# media
# whole
# seem
# try
# ignore
# u
# s
# subsidizing
# israels
# existance
# europeans
# least
# degree
# think
# might
# reason
# report
# clearly
# atrocities
# shame
# austria
# daily
# reports
# inhuman
# acts
# commited
# israeli
# soldiers
# blessing
# received
# government
# makes
# holocaust
# guilt
# go
# away
# look
# jews
# treating
# races
# got
# power
# unfortunate
# yeah
# expect
# people
# read
# faq
# etc
# actually
# accept
# hard
# atheism
# need
# little
# leap
# faith
# jimmy
# logic
# runs
# steam
# jim
# sorry
# can
# t
# pity
# jim
# m
# sorry
# feelings
# denial
# faith
# need
# get
# oh
# well
# just
# pretend
# will
# end
# happily
# ever
# anyway
# maybe
# start
# new
# newsgroup
# alt
# ...

# %%
import random
f=open("20news.txt", "w")
for  i in range(100):
    index = random.randint(0,len(texts)-1)
    f.write(" ".join(texts[index])+"\n")
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-61b26d10551b> in <module>()
#       7
#       8 dictf=open("20news.dict", "w")
# ----> 9 for line in dic:
#      10     dictf.write(line+"\n")
#      11     print(line)
#
# NameError: name 'dic' is not defined

# %%
dic = set()
for line in texts:
    dic.update(set(line))
print(dic)

# %%
import random
f=open("20news.txt", "w")
for  i in range(100):
    index = random.randint(0,len(texts)-1)
    f.write(" ".join(texts[index])+"\n")
f.close()

# %%
dictf=open("20news-big.dict", "w")
for line in dic:
    dictf.write(line+"\n")
    print(line)
    #dictf.write("55555555555")
dictf.close()
